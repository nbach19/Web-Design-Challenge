# %%
import pandas as pd

# %%
weather_data = 'weather_data.csv'

# %%
weather_df = pd.read_csv(weather_data)
weather_df
# Out:
#                City    Lat     Lon  Max Temp  Humidity  Wind Speed Country  \
# 0    saint-philippe -21.36   55.77     77.00        78        4.70      RE
# 1            hobart -42.88  147.33     62.60        48       24.16      AU
# 2              juba   4.85   31.58     83.93        24        4.99      SS
# 3            dikson  73.51   80.55     14.25        89       24.14      RU
# 4            barrow  71.29 -156.79    -27.40        74        3.36      US
# ..              ...    ...     ...       ...       ...         ...     ...
# 571          alugan  12.22  125.48     78.85        84       15.97      PH
# 572      solnechnyy  50.72  136.63     17.13        80        0.69      RU
# 573     panalingaan   8.78  117.42     79.32        76        6.98      PH
# 574          akdepe  42.06   59.38     26.60        73        4.70      TM
# 575         amuntai  -2.42  115.25     77.04        93        1.16      ID
#
#            Date  Clouds
# 0    1582766425      92
# 1    1582766418      75
# 2    1582766425       1
# 3    1582766425     100
# 4    1582766425       1
# ..          ...     ...
# 571  1582766553      88
# 572  1582766553      20
# 573  1582766553      94
# 574  1582766553      48
# 575  1582766455     100
#
# [576 rows x 9 columns]

# %%
weather_df = weather_df.drop(columns="Date")
weather_df
# Out:
#                City    Lat     Lon  Max Temp  Humidity  Wind Speed Country  \
# 0    saint-philippe -21.36   55.77     77.00        78        4.70      RE
# 1            hobart -42.88  147.33     62.60        48       24.16      AU
# 2              juba   4.85   31.58     83.93        24        4.99      SS
# 3            dikson  73.51   80.55     14.25        89       24.14      RU
# 4            barrow  71.29 -156.79    -27.40        74        3.36      US
# ..              ...    ...     ...       ...       ...         ...     ...
# 571          alugan  12.22  125.48     78.85        84       15.97      PH
# 572      solnechnyy  50.72  136.63     17.13        80        0.69      RU
# 573     panalingaan   8.78  117.42     79.32        76        6.98      PH
# 574          akdepe  42.06   59.38     26.60        73        4.70      TM
# 575         amuntai  -2.42  115.25     77.04        93        1.16      ID
#
#      Clouds
# 0        92
# 1        75
# 2         1
# 3       100
# 4         1
# ..      ...
# 571      88
# 572      20
# 573      94
# 574      48
# 575     100
#
# [576 rows x 8 columns]

# %%
html = weather_df.to_html()

# %%
text_file = open("data.html", "w")
text_file.write(html)
text_file.close()
